# %%
# !pip install -U googlemaps
# Out:
# Requirement already satisfied: googlemaps in d:\anaconda\lib\site-packages (4.4.7)
# Requirement already satisfied: requests<3.0,>=2.20.0 in d:\anaconda\lib\site-packages (from googlemaps) (2.25.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in d:\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2020.12.5)

# %%
import requests
import os
from bs4 import BeautifulSoup
import socks
import pandas as pd
import numpy as np

# %%
table = pd.read_excel(r'C:\\Users\79192\Desktop\project1\data_.xlsx')

# %%
table
# Out:
#                                          organization  \
# 0   X-FIT г. Альметьевск, ул. Ленина, д. 140, ТЦ ?...
# 1   Fit-Studio г. Ангарск 192-ой квартал, ФОК Комс...
# 2    Fit-Studio г.Астрахань, ул. Адмиралтейская д. 29
# 3           Fit-Studio  г.Балезино, ул.Сибирская, д.8
# 4    X-FIT г. Барнаул\nпр. Красноармейский, д. 47а...
# 5            Fit-Studio г. Белебей, ул. Ленина, дом 5
# 6   Fit-Studio  г.Брянск, ул. Красноармейская, д. 100
# 7              X-FIT г. Владимир,ул. Ново-Ямская, 79е
# 8   Fit-Studio г. Воронеж, ул. Старых Большевиков,...
# 9           Fit-Studio г. Воронеж, ул. Минская, д. 79
# 10           X-FIT г. Геленджик\nпер. Сосновый, д. 7
# 11  Fit-Studio г. Москва\nДолгопрудненское шоссе, ...
# 12            X-FIT г. Душанбе ул. Мухаммадиева, 24/2
# 13            X-FIT г.Екатеринбург, ул.Шейнкмана, 121
# 14       Fit-Studio г. Звенигород\nул. Чехова, д. 13а
# 15  X-FIT г. Иркутск\nул. Советская, д. 58, МТЦ Новый
# 16            X-FIT г. Калининград, ул. Бассейная, 46
# 17    X-FIT г. Канск, ул. 40 лет Октября, д.62, стр.4
# 18    X-FIT г. Кинешма\nул. 50-летия Комсомола, д. 24
# 19                X-FIT г. Ковров\nул. Чкалова, д. 51
# 20  X-FIT  г. Когалым, ул. Дружбы Народов, д. 60, ...
# 21      Fit-Studio г. Краснодар\nул. Суворова, д. 91
# 22  X-FIT г. Краснодар\nул. Архитектора Ишунина, д...
# 23  X-FIT г. Краснодар\nБульвар им. Клары Лучко, д. 1
# 24                 X-FIT г.Кстово, ул. Зеленая, д. 24
# 25         Fit-Studio г.Магадан, ул. Коммуны, д. 17/А
# 26  X-FIT г. Москва\nпоселок Малаховка, Быковское ...
# 27                     Fit-Studio г. Минск Кнорина 17
# 28  X-FIT г. Минск пр-т. Независимости, д. 173, би...
# 29                Fit-Studio Москва ул. Смоленская, 8
# 30     Fit-Studio г. Москва, Можайское шоссе д 38 к 1
# 31  X-FIT г. Москва\nул. Маршала Савицкого, д. 7 (...
# 32          X-FIT г. Мурманск\nул. Гвардейская, д. 1A
# 33          X-FIT г. Нижнекамск\nул. Студенческая, 44
# 34                   X-FIT ул. Дмитрия Павлова, д. 13
# 35      Fit-Studio  г.Новороссийск, ул. Куникова 28-А
# 36           X-FIT г. Норильск ул. 50 лет Октября, 6.
# 37          X-FIT г. Норильск\nпл. Металлургов, д. 10
# 38  Fit-Studio г. Павловский Посад, ул. Большая По...
# 39           X-FIT г. Прокопьевск, ул. Гайдара 50 "А"
# 40  X-FIT г. Пушкино\nул. Чехова, д. 12, ТЦ ВИТ, 8...
# 41     X-FIT  г. Россошь\nул. Пл. Октябрьская, д. 18а
# 42             X-FIT г. Саранск\nул. Советская, д. 75
# 43          X-FIT г. Ставрополь\nул. Васильева, д. 2
# 44  Fit-Studio  г. Старый Оскол\nмикрорайон Ольмин...
# 45  Fit-Studio г. Уфа\nКалининский р-н, Бульвар Ба...
# 46  Fit-Studio г.Череповец, проспект Победы 93, ТК...
# 47                     X-FIT  г.Чита, ул. Шилова, 97д
# 48    X-FIT М.О., д. Каменное Тяжино, ул. Заречная, 2
# 49        Fit-Studio г. Юрга\nул. Волгоградская д. 2а
# 50  Fit-Studio   г. Якутск, ул. Дзержинского, д. 3...
#
#                 place_id_google  \
# 0   ChIJz67_bINdYEERHJhwivP0E8s
# 1   ChIJ1yLK6YicB10R3m5PBFQtXh4
# 2   ChIJDzh-84EFqUERQAxsAX8N1DY
# 3   ChIJTRLsZnVc5EMRIhL83QFqYEg
# 4   ChIJNcPSGTik3UIRB32olkk3RV4
# 5   ChIJF6E3xX8XYkERc-CZEbvE6Kg
# 6   ChIJd4RqNFdYLUERk3dOz7Mvp7Q
# 7                           NaN
# 8   ChIJOS76nrwoO0ERUv_8816d_FY
# 9   ChIJe67FUYgvO0ERKUvP-vtUY8Q
# 10  ChIJ-wWiGRiK8UARQQ2rM0Lhhjw
# 11  ChIJH7SoVYk5tUYRuBrib1kP_ps
# 12  ChIJR-RA-xjStTgRXOmHHVlELHs
# 13  ChIJdYJbdOZuwUMRCTfRiYMSIis
# 14  ChIJ1ZxNmrxgtUYR6v5LJ-1FuhI
# 15  ChIJrTShjEI7qF0ReJPuXh1mg-k
# 16  ChIJq-VbPcM940YR6cpR2lee0jE
# 17  ChIJn1SXGHrT3lwRYsUjIyjwYlQ
# 18  ChIJOeLa51iTUkERkN9dgA7jyXM
# 19  ChIJh0xqklNITEERI57cMP5Oq1k
# 20  ChIJ_____97ocUMRgfoZLm8I2w0
# 21  ChIJAfkB0MdP8EARCfPJRiOaAdQ
# 22  ChIJcyCWo_FF8EAROKsTML63s4Y
# 23  ChIJs3_kfthO8EARwcq5BfU7UA8
# 24  ChIJWVaI27bXT0ERR_mksqjOK8g
# 25  ChIJQWunNDmIaVkRHrgR5fno2rw
# 26  ChIJeR9LgEC5SkER3HEr-mWSq7s
# 27  ChIJjTk0rAXP20YRDX01eC2yuHk
# 28  ChIJxzbJBh3P20YRJjZWm-WctwM
# 29                          NaN
# 30  ChIJE1UIXShPtUYRGCN7Fib5xdY
# 31  ChIJ56xZyPyvSkER0PEgTOoiMCk
# 32  ChIJuaDakdwPNEQRx-Eeb3nBoc8
# 33                          NaN
# 34  ChIJldHLZ0vWUUERXlvEPbl4Mpw
# 35  ChIJNXGdeVf48UARfO9K8SxBcR4
# 36  ChIJAQAkIxtcrEQRliQoDtJ6vZU
# 37  ChIJAQAkIxtcrEQRliQoDtJ6vZU
# 38  ChIJZeG_Ro3gSkERtuN1fKoCEwo
# 39  ChIJk4hDCO0J2kIRZ0GEx5tA7JI
# 40  ChIJkQcVHysvtUYR7KTmrsBrphc
# 41  ChIJ8cVgLFk1IkERi2gX_L-7tdQ
# 42                          NaN
# 43  ChIJ87Q3AUUH-UARDWJFWuYpElI
# 44  ChIJXw_sjTsJJUEROUs4UBX9VGs
# 45  ChIJcwRAzHc42UMRYjhcaBZFmSA
# 46  ChIJZxsPnFW2r0YRhhKSt96wdT4
# 47  ChIJY_PpGJ9Kyl0R15IUdf35X_4
# 48                          NaN
# 49                          NaN
# 50  ChIJb5ZiPElK9lsR69jmd49rY6U
#
#                                            URL_yandex
# 0   https://yandex.ru/maps/org/x_fit/92294897678/?...
# 1   https://yandex.ru/maps/org/fitstudio/191379856...
# 2   https://yandex.ru/maps/org/x_fit_studio/166550...
# 3   https://yandex.ru/maps/org/fitstudio/185512744...
# 4   https://yandex.ru/maps/org/x_fit/223779873763/...
# 5   https://yandex.ru/maps/org/fitstudio/817143494...
# 6   https://yandex.ru/maps/org/fit_studio/16807274...
# 7   https://yandex.ru/maps/org/x_fit/8495664975/?l...
# 8   https://yandex.ru/maps/org/fitstudio/134837988...
# 9   https://yandex.ru/maps/org/kratos/1801488397/?...
# 10  https://yandex.ru/maps/org/x_fit/171581666269/...
# 11  https://yandex.ru/maps/org/x_fit_studio_fitnes...
# 12  https://yandex.ru/maps/org/x_fit/108874440691/...
# 13  https://yandex.ru/maps/org/antares_x_fit_premi...
# 14  https://yandex.ru/maps/org/x_fit_studio/169916...
# 15  https://yandex.ru/maps/org/x_fit/116518719596/...
# 16  https://yandex.ru/maps/org/x_fit/160822342154/...
# 17  https://yandex.ru/maps/org/x_fit/158092274037/...
# 18  https://yandex.ru/maps/org/x_fit_kineshma/1044...
# 19  https://yandex.ru/maps/org/x_fit/35012091946/?...
# 20  https://yandex.ru/maps/org/x_fit_galaktika/662...
# 21  https://yandex.ru/maps/org/x_fit_studio_tsentr...
# 22  https://yandex.ru/maps/org/fitnes_klub_x_fit_s...
# 23  https://yandex.ru/maps/org/fitnes_klub_x_fit_y...
# 24  https://yandex.ru/maps/org/fitnes_tsentr_fit_s...
# 25  https://yandex.ru/maps/org/fitstudio/191125696...
# 26  https://yandex.ru/maps/org/x_fit_nika/20944316...
# 27  https://yandex.ru/maps/org/x_fit_studio/287575...
# 28  https://yandex.ru/maps/org/x_fit_futuris/48016...
# 29  https://yandex.ru/maps/org/x_fit/29279034080/?...
# 30  https://yandex.ru/maps/org/fit_studio/40588218...
# 31  https://yandex.ru/maps/org/x_fit/240012922388/...
# 32  https://yandex.ru/maps/org/x_fit/228947883319/...
# 33  https://yandex.ru/maps/org/x_fit/127116313978/...
# 34  https://yandex.ru/maps/org/x_fit/1784855807/?l...
# 35  https://yandex.ru/maps/org/x_fit/25499638995/?...
# 36  https://yandex.ru/maps/org/x_fit/139516399473/...
# 37  https://yandex.ru/maps/org/x_fit/1759913063/?l...
# 38  https://yandex.ru/maps/org/fitstudio/387258546...
# 39  https://yandex.ru/maps/org/x_fit/35091467221/?...
# 40  https://yandex.ru/maps/org/fitnes_klub_x_fit_p...
# 41  https://yandex.ru/maps/org/x_fit/49694263018/?...
# 42  https://yandex.ru/maps/org/x_fit/216140536281/...
# 43  https://yandex.ru/maps/org/kh_fit/1797498908/?...
# 44  https://yandex.ru/maps/org/x_fit/69134251961/?...
# 45  https://yandex.ru/maps/org/fitnes_klub_fit_stu...
# 46  https://yandex.ru/maps/org/fitstudio/186731480...
# 47  https://yandex.ru/maps/org/x_fit/167070783450/...
# 48  https://yandex.ru/maps/org/chulkovo_club/12964...
# 49  https://yandex.ru/maps/org/x_fit/94047955195/?...
# 50  https://yandex.ru/maps/org/fit_studio/15966534...

# %%
def get_result(url):
    rs = requests.session()
    #rs.proxies['http'] = os.getenv("proxy", "socks5h://localhost:9150")  # что передается?
    #rs.proxies['https'] = os.getenv("proxy", "socks5h://localhost:9150")
    rs.headers['User-Agent'] = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36'
    rs.headers['Accept-Language'] = 'Accept-Language: en-US,en;q=0.5'
    result = rs.get(url, timeout=1000)
    rs.close()
    return result

# %%
def get_rating_yandex(html):
    
    rating = html.find('div', class_ = 'orgpage-header-view__rating-wrapper').find_all('span', class_='business-rating-badge-view__rating-text _size_m')
    if len(rating)!=0:
        rating = rating[0].text
    else:
        rating = "No data"
    return rating

# %%
def get_work_status_yandex(html):
    working_status = html.find('div', class_ = 'orgpage-header-view__working-status').text
    return working_status

# %%
def get_organization_type_yandex(html):
    org_statuses = [elem.text for elem in html.find_all('a', class_ = 'breadcrumbs-view__breadcrumb')]
    
    return org_statuses

# %%
def get_results_google(place_id):
    if place_id is not np.nan:
        try:
            result=gmaps.place(place_id=place_id,fields=['name', 'rating', 'business_status', 'type'])
        except:
            rating = "No data"
            working_status = "No data"
            organization_type_is_correct = "No data"
        try:
            rating=result['result']['rating']
        except:
            rating = "No data"
        try:
            working_status = result['result']['business_status']
        except:
            working_status = "No data"
        try:
            if ('gym' not in result['result']['types']):
                organization_type_is_correct = "ERROR"
            else:
                organization_type_is_correct = "ok"
        except:
            organization_type_is_correct = "No data"
    else:
        rating = "No data"
        working_status = "No data"
        organization_type_is_correct = "No data"
    return [rating,working_status,organization_type_is_correct]

# %%
rating_yandex = []
working_status_yandex = []
organization_type_is_correct_yandex = []
for url in table['URL_yandex']:
    if url is not np.nan:
        response = get_result(url)
        soup = BeautifulSoup(response.text,'lxml')
        rating_yandex.append(get_rating_yandex(soup))
        working_status_yandex.append(get_work_status_yandex(soup))
        types = get_organization_type_yandex(soup)
        if (('Фитнес-клубы' not in types) and ('Спортзалы' not in types)):
            organization_type_is_correct_yandex.append('ERROR')
        else:
            organization_type_is_correct_yandex.append('ok')
    else:
        rating_yandex.append("no_data")
        working_status_yandex.append("no_data")
        organization_type_is_correct_yandex.append("no_data")

# %%
file = open(r'C:\Users\79192\Desktop\project1\key.txt', 'r')
API_TOKEN= file.read()
file.close()
import googlemaps
gmaps = googlemaps.Client(key=API_TOKEN)

# %%
rating_google = []
working_status_google = []
organization_type_is_correct_google = []
for place_id in table['place_id_google']:
    result = get_results_google(place_id)
    rating_google.append(result[0])
    working_status_google.append(result[1])
    organization_type_is_correct_google.append(result[2])

# %%
table['rating_yandex'] = rating_yandex
table['rating_google'] = rating_google
table['working_status_yandex'] = working_status_yandex
table['organization_type_is_correct_yandex_(Корректно, если type = Фитнес-клубы или Спортзалы)'] = organization_type_is_correct_yandex
table['working_status_google'] = working_status_google
table['organization_type_is_correct_google'] = organization_type_is_correct_google
#table['Organization'] =  pd.read_csv(r'C:\\Users\79192\Desktop\project1\data.csv', usecols=['organization'])

# %%
table
# Out:
#                                          organization  \
# 0   X-FIT г. Альметьевск, ул. Ленина, д. 140, ТЦ ?...
# 1   Fit-Studio г. Ангарск 192-ой квартал, ФОК Комс...
# 2    Fit-Studio г.Астрахань, ул. Адмиралтейская д. 29
# 3           Fit-Studio  г.Балезино, ул.Сибирская, д.8
# 4    X-FIT г. Барнаул\nпр. Красноармейский, д. 47а...
# 5            Fit-Studio г. Белебей, ул. Ленина, дом 5
# 6   Fit-Studio  г.Брянск, ул. Красноармейская, д. 100
# 7              X-FIT г. Владимир,ул. Ново-Ямская, 79е
# 8   Fit-Studio г. Воронеж, ул. Старых Большевиков,...
# 9           Fit-Studio г. Воронеж, ул. Минская, д. 79
# 10           X-FIT г. Геленджик\nпер. Сосновый, д. 7
# 11  Fit-Studio г. Москва\nДолгопрудненское шоссе, ...
# 12            X-FIT г. Душанбе ул. Мухаммадиева, 24/2
# 13            X-FIT г.Екатеринбург, ул.Шейнкмана, 121
# 14       Fit-Studio г. Звенигород\nул. Чехова, д. 13а
# 15  X-FIT г. Иркутск\nул. Советская, д. 58, МТЦ Новый
# 16            X-FIT г. Калининград, ул. Бассейная, 46
# 17    X-FIT г. Канск, ул. 40 лет Октября, д.62, стр.4
# 18    X-FIT г. Кинешма\nул. 50-летия Комсомола, д. 24
# 19                X-FIT г. Ковров\nул. Чкалова, д. 51
# 20  X-FIT  г. Когалым, ул. Дружбы Народов, д. 60, ...
# 21      Fit-Studio г. Краснодар\nул. Суворова, д. 91
# 22  X-FIT г. Краснодар\nул. Архитектора Ишунина, д...
# 23  X-FIT г. Краснодар\nБульвар им. Клары Лучко, д. 1
# 24                 X-FIT г.Кстово, ул. Зеленая, д. 24
# 25         Fit-Studio г.Магадан, ул. Коммуны, д. 17/А
# 26  X-FIT г. Москва\nпоселок Малаховка, Быковское ...
# 27                     Fit-Studio г. Минск Кнорина 17
# 28  X-FIT г. Минск пр-т. Независимости, д. 173, би...
# 29                Fit-Studio Москва ул. Смоленская, 8
# 30     Fit-Studio г. Москва, Можайское шоссе д 38 к 1
# 31  X-FIT г. Москва\nул. Маршала Савицкого, д. 7 (...
# 32          X-FIT г. Мурманск\nул. Гвардейская, д. 1A
# 33          X-FIT г. Нижнекамск\nул. Студенческая, 44
# 34                   X-FIT ул. Дмитрия Павлова, д. 13
# 35      Fit-Studio  г.Новороссийск, ул. Куникова 28-А
# 36           X-FIT г. Норильск ул. 50 лет Октября, 6.
# 37          X-FIT г. Норильск\nпл. Металлургов, д. 10
# 38  Fit-Studio г. Павловский Посад, ул. Большая По...
# 39           X-FIT г. Прокопьевск, ул. Гайдара 50 "А"
# 40  X-FIT г. Пушкино\nул. Чехова, д. 12, ТЦ ВИТ, 8...
# 41     X-FIT  г. Россошь\nул. Пл. Октябрьская, д. 18а
# 42             X-FIT г. Саранск\nул. Советская, д. 75
# 43          X-FIT г. Ставрополь\nул. Васильева, д. 2
# 44  Fit-Studio  г. Старый Оскол\nмикрорайон Ольмин...
# 45  Fit-Studio г. Уфа\nКалининский р-н, Бульвар Ба...
# 46  Fit-Studio г.Череповец, проспект Победы 93, ТК...
# 47                     X-FIT  г.Чита, ул. Шилова, 97д
# 48    X-FIT М.О., д. Каменное Тяжино, ул. Заречная, 2
# 49        Fit-Studio г. Юрга\nул. Волгоградская д. 2а
# 50  Fit-Studio   г. Якутск, ул. Дзержинского, д. 3...
#
#                 place_id_google  \
# 0   ChIJz67_bINdYEERHJhwivP0E8s
# 1   ChIJ1yLK6YicB10R3m5PBFQtXh4
# 2   ChIJDzh-84EFqUERQAxsAX8N1DY
# 3   ChIJTRLsZnVc5EMRIhL83QFqYEg
# 4   ChIJNcPSGTik3UIRB32olkk3RV4
# 5   ChIJF6E3xX8XYkERc-CZEbvE6Kg
# 6   ChIJd4RqNFdYLUERk3dOz7Mvp7Q
# 7                           NaN
# 8   ChIJOS76nrwoO0ERUv_8816d_FY
# 9   ChIJe67FUYgvO0ERKUvP-vtUY8Q
# 10  ChIJ-wWiGRiK8UARQQ2rM0Lhhjw
# 11  ChIJH7SoVYk5tUYRuBrib1kP_ps
# 12  ChIJR-RA-xjStTgRXOmHHVlELHs
# 13  ChIJdYJbdOZuwUMRCTfRiYMSIis
# 14  ChIJ1ZxNmrxgtUYR6v5LJ-1FuhI
# 15  ChIJrTShjEI7qF0ReJPuXh1mg-k
# 16  ChIJq-VbPcM940YR6cpR2lee0jE
# 17  ChIJn1SXGHrT3lwRYsUjIyjwYlQ
# 18  ChIJOeLa51iTUkERkN9dgA7jyXM
# 19  ChIJh0xqklNITEERI57cMP5Oq1k
# 20  ChIJ_____97ocUMRgfoZLm8I2w0
# 21  ChIJAfkB0MdP8EARCfPJRiOaAdQ
# 22  ChIJcyCWo_FF8EAROKsTML63s4Y
# 23  ChIJs3_kfthO8EARwcq5BfU7UA8
# 24  ChIJWVaI27bXT0ERR_mksqjOK8g
# 25  ChIJQWunNDmIaVkRHrgR5fno2rw
# 26  ChIJeR9LgEC5SkER3HEr-mWSq7s
# 27  ChIJjTk0rAXP20YRDX01eC2yuHk
# 28  ChIJxzbJBh3P20YRJjZWm-WctwM
# 29                          NaN
# 30  ChIJE1UIXShPtUYRGCN7Fib5xdY
# 31  ChIJ56xZyPyvSkER0PEgTOoiMCk
# 32  ChIJuaDakdwPNEQRx-Eeb3nBoc8
# 33                          NaN
# 34  ChIJldHLZ0vWUUERXlvEPbl4Mpw
# 35  ChIJNXGdeVf48UARfO9K8SxBcR4
# 36  ChIJAQAkIxtcrEQRliQoDtJ6vZU
# 37  ChIJAQAkIxtcrEQRliQoDtJ6vZU
# 38  ChIJZeG_Ro3gSkERtuN1fKoCEwo
# 39  ChIJk4hDCO0J2kIRZ0GEx5tA7JI
# 40  ChIJkQcVHysvtUYR7KTmrsBrphc
# 41  ChIJ8cVgLFk1IkERi2gX_L-7tdQ
# 42                          NaN
# 43  ChIJ87Q3AUUH-UARDWJFWuYpElI
# 44  ChIJXw_sjTsJJUEROUs4UBX9VGs
# 45  ChIJcwRAzHc42UMRYjhcaBZFmSA
# 46  ChIJZxsPnFW2r0YRhhKSt96wdT4
# 47  ChIJY_PpGJ9Kyl0R15IUdf35X_4
# 48                          NaN
# 49                          NaN
# 50  ChIJb5ZiPElK9lsR69jmd49rY6U
#
#                                            URL_yandex rating_yandex  \
# 0   https://yandex.ru/maps/org/x_fit/92294897678/?...           4,4
# 1   https://yandex.ru/maps/org/fitstudio/191379856...           4,5
# 2   https://yandex.ru/maps/org/x_fit_studio/166550...           4,4
# 3   https://yandex.ru/maps/org/fitstudio/185512744...           4,4
# 4   https://yandex.ru/maps/org/x_fit/223779873763/...           4,6
# 5   https://yandex.ru/maps/org/fitstudio/817143494...           4,1
# 6   https://yandex.ru/maps/org/fit_studio/16807274...           4,3
# 7   https://yandex.ru/maps/org/x_fit/8495664975/?l...           4,8
# 8   https://yandex.ru/maps/org/fitstudio/134837988...           4,3
# 9   https://yandex.ru/maps/org/kratos/1801488397/?...           4,1
# 10  https://yandex.ru/maps/org/x_fit/171581666269/...           4,8
# 11  https://yandex.ru/maps/org/x_fit_studio_fitnes...           4,6
# 12  https://yandex.ru/maps/org/x_fit/108874440691/...           4,4
# 13  https://yandex.ru/maps/org/antares_x_fit_premi...           4,7
# 14  https://yandex.ru/maps/org/x_fit_studio/169916...           4,6
# 15  https://yandex.ru/maps/org/x_fit/116518719596/...           4,7
# 16  https://yandex.ru/maps/org/x_fit/160822342154/...           4,8
# 17  https://yandex.ru/maps/org/x_fit/158092274037/...       No data
# 18  https://yandex.ru/maps/org/x_fit_kineshma/1044...           4,8
# 19  https://yandex.ru/maps/org/x_fit/35012091946/?...           4,8
# 20  https://yandex.ru/maps/org/x_fit_galaktika/662...           4,6
# 21  https://yandex.ru/maps/org/x_fit_studio_tsentr...           4,4
# 22  https://yandex.ru/maps/org/fitnes_klub_x_fit_s...           4,8
# 23  https://yandex.ru/maps/org/fitnes_klub_x_fit_y...           4,9
# 24  https://yandex.ru/maps/org/fitnes_tsentr_fit_s...           4,5
# 25  https://yandex.ru/maps/org/fitstudio/191125696...           4,4
# 26  https://yandex.ru/maps/org/x_fit_nika/20944316...           4,3
# 27  https://yandex.ru/maps/org/x_fit_studio/287575...           2,4
# 28  https://yandex.ru/maps/org/x_fit_futuris/48016...           4,9
# 29  https://yandex.ru/maps/org/x_fit/29279034080/?...           4,2
# 30  https://yandex.ru/maps/org/fit_studio/40588218...           4,6
# 31  https://yandex.ru/maps/org/x_fit/240012922388/...           5,0
# 32  https://yandex.ru/maps/org/x_fit/228947883319/...           5,0
# 33  https://yandex.ru/maps/org/x_fit/127116313978/...           4,4
# 34  https://yandex.ru/maps/org/x_fit/1784855807/?l...           4,7
# 35  https://yandex.ru/maps/org/x_fit/25499638995/?...       No data
# 36  https://yandex.ru/maps/org/x_fit/139516399473/...       No data
# 37  https://yandex.ru/maps/org/x_fit/1759913063/?l...           4,4
# 38  https://yandex.ru/maps/org/fitstudio/387258546...           4,1
# 39  https://yandex.ru/maps/org/x_fit/35091467221/?...           4,6
# 40  https://yandex.ru/maps/org/fitnes_klub_x_fit_p...           4,7
# 41  https://yandex.ru/maps/org/x_fit/49694263018/?...           3,7
# 42  https://yandex.ru/maps/org/x_fit/216140536281/...           4,5
# 43  https://yandex.ru/maps/org/kh_fit/1797498908/?...           5,0
# 44  https://yandex.ru/maps/org/x_fit/69134251961/?...           4,9
# 45  https://yandex.ru/maps/org/fitnes_klub_fit_stu...           4,2
# 46  https://yandex.ru/maps/org/fitstudio/186731480...           4,7
# 47  https://yandex.ru/maps/org/x_fit/167070783450/...           4,4
# 48  https://yandex.ru/maps/org/chulkovo_club/12964...           4,6
# 49  https://yandex.ru/maps/org/x_fit/94047955195/?...           4,4
# 50  https://yandex.ru/maps/org/fit_studio/15966534...           4,8
#
#    rating_google    working_status_yandex  \
# 0            4.8         Открыто до 23:00
# 1            4.6         Открыто до 23:00
# 2            4.5         Открыто до 22:00
# 3            4.3         Открыто до 23:00
# 4            4.9         Открыто до 21:00
# 5            4.7         Открыто до 23:00
# 6            4.5         Открыто до 21:30
# 7        No data         Открыто до 22:00
# 8            4.5         Открыто до 22:00
# 9        No data         Открыто до 22:00
# 10           4.7         Открыто до 22:00
# 11           4.6         Открыто до 22:00
# 12           4.6         Открыто до 23:00
# 13             5         Открыто до 23:00
# 14           4.3         Открыто до 22:00
# 15           4.6         Открыто до 23:00
# 16           4.9         Открыто до 23:00
# 17             5         Открыто до 22:00
# 18             5         Открыто до 22:00
# 19           4.8         Открыто до 22:00
# 20           4.8         Открыто до 00:00
# 21           4.6            Круглосуточно
# 22           4.5         Открыто до 00:00
# 23           4.5         Открыто до 00:00
# 24           4.6         Открыто до 23:00
# 25           4.3         Открыто до 23:00
# 26           4.5         Открыто до 00:00
# 27           4.6         Открыто до 23:00
# 28           4.3         Открыто до 23:00
# 29       No data         Открыто до 23:00
# 30           4.7         Открыто до 23:00
# 31           4.7         Открыто до 00:00
# 32           4.7         Открыто до 23:00
# 33       No data         Открыто до 23:00
# 34           4.6         Открыто до 23:30
# 35           4.3         Открыто до 21:00
# 36           4.4  График работы не указан
# 37           4.4         Открыто до 23:00
# 38           4.1         Открыто до 23:00
# 39             5         Открыто до 23:00
# 40           4.6         Открыто до 00:00
# 41             5  График работы не указан
# 42       No data         Открыто до 22:00
# 43           4.7         Открыто до 23:00
# 44           4.5         Открыто до 23:00
# 45           4.7         Открыто до 23:00
# 46           4.8         Открыто до 22:30
# 47           4.5         Открыто до 22:00
# 48       No data         Открыто до 23:00
# 49       No data  График работы не указан
# 50           4.8         Открыто до 23:00
#
#    organization_type_is_correct_yandex_(Корректно, если type = Фитнес-клубы или Спортзалы)  \
# 0                                                  ok
# 1                                                  ok
# 2                                                  ok
# 3                                                  ok
# 4                                                  ok
# 5                                                  ok
# 6                                                  ok
# 7                                                  ok
# 8                                                  ok
# 9                                                  ok
# 10                                                 ok
# 11                                                 ok
# 12                                                 ok
# 13                                                 ok
# 14                                                 ok
# 15                                                 ok
# 16                                                 ok
# 17                                                 ok
# 18                                                 ok
# 19                                                 ok
# 20                                                 ok
# 21                                                 ok
# 22                                                 ok
# 23                                                 ok
# 24                                                 ok
# 25                                                 ok
# 26                                                 ok
# 27                                                 ok
# 28                                                 ok
# 29                                                 ok
# 30                                                 ok
# 31                                                 ok
# 32                                                 ok
# 33                                                 ok
# 34                                                 ok
# 35                                                 ok
# 36                                                 ok
# 37                                                 ok
# 38                                                 ok
# 39                                                 ok
# 40                                                 ok
# 41                                                 ok
# 42                                                 ok
# 43                                                 ok
# 44                                                 ok
# 45                                                 ok
# 46                                                 ok
# 47                                                 ok
# 48                                                 ok
# 49                                                 ok
# 50                                                 ok
#
#    working_status_google organization_type_is_correct_google
# 0            OPERATIONAL                                  ok
# 1            OPERATIONAL                                  ok
# 2            OPERATIONAL                                  ok
# 3            OPERATIONAL                                  ok
# 4            OPERATIONAL                                  ok
# 5            OPERATIONAL                                  ok
# 6            OPERATIONAL                                  ok
# 7                No data                             No data
# 8            OPERATIONAL                                  ok
# 9            OPERATIONAL                               ERROR
# 10           OPERATIONAL                                  ok
# 11           OPERATIONAL                                  ok
# 12           OPERATIONAL                                  ok
# 13           OPERATIONAL                               ERROR
# 14           OPERATIONAL                                  ok
# 15           OPERATIONAL                                  ok
# 16           OPERATIONAL                               ERROR
# 17           OPERATIONAL                                  ok
# 18           OPERATIONAL                                  ok
# 19           OPERATIONAL                                  ok
# 20           OPERATIONAL                                  ok
# 21           OPERATIONAL                                  ok
# 22           OPERATIONAL                                  ok
# 23           OPERATIONAL                                  ok
# 24           OPERATIONAL                                  ok
# 25           OPERATIONAL                                  ok
# 26           OPERATIONAL                                  ok
# 27           OPERATIONAL                                  ok
# 28           OPERATIONAL                               ERROR
# 29               No data                             No data
# 30           OPERATIONAL                                  ok
# 31           OPERATIONAL                                  ok
# 32           OPERATIONAL                                  ok
# 33               No data                             No data
# 34           OPERATIONAL                                  ok
# 35           OPERATIONAL                                  ok
# 36           OPERATIONAL                                  ok
# 37           OPERATIONAL                                  ok
# 38           OPERATIONAL                                  ok
# 39           OPERATIONAL                                  ok
# 40           OPERATIONAL                               ERROR
# 41           OPERATIONAL                                  ok
# 42               No data                             No data
# 43           OPERATIONAL                                  ok
# 44           OPERATIONAL                                  ok
# 45           OPERATIONAL                                  ok
# 46           OPERATIONAL                                  ok
# 47           OPERATIONAL                                  ok
# 48               No data                             No data
# 49               No data                             No data
# 50           OPERATIONAL                                  ok

# %%
table.to_excel(r'C:\\Users\79192\Desktop\project1\rating_list.xlsx', )
